# %% [markdown]
# # CPD using TIRE

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.models import Model

import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from scipy.signal import find_peaks, peak_prominences
import warnings
import time, copy

import utils
import TIRE
import simulate
import math

# %% [markdown]
# ## Set parameters

# %% [markdown]
# #### alpha settings

# %%
# window_size = 100
# domain = "both" #choose from: TD (time domain), FD (frequency domain) or both

# #parameters TD
# intermediate_dim_TD=0
# latent_dim_TD=1 #h^TD in paper
# nr_shared_TD=1 #s^TD in paper
# K_TD = 2 #as in paper
# nr_ae_TD= K_TD+1 #number of parallel AEs = K+1
# loss_weight_TD=1 #lambda_TD in paper

# #parameters FD
# intermediate_dim_FD=0
# latent_dim_FD=1 #h^FD in paper
# nr_shared_FD=1 #s^FD in paper
# K_FD = 2 #as in paper
# nr_ae_FD=K_FD+1 #number of parallel AEs = K+1
# loss_weight_FD=1 #lambda^FD in paper
# nfft = 30 #number of points for DFT
# norm_mode = "timeseries" #for calculation of DFT, should the timeseries have mean zero or each window?
# type_setting = 'alpha'

# %% [markdown]
# #### beta settings

# %%
window_size = 100
domain = "both" #choose from: TD (time domain), FD (frequency domain) or both

#parameters TD
intermediate_dim_TD=0
latent_dim_TD=3 #h^TD in paper
nr_shared_TD=2 #s^TD in paper
K_TD = 2 #as in paper
nr_ae_TD= K_TD+1 #number of parallel AEs = K+1
loss_weight_TD=1 #lambda_TD in paper

#parameters FD
intermediate_dim_FD=10
latent_dim_FD=1 #h^FD in paper
nr_shared_FD=1 #s^FD in paper
K_FD = 2 #as in paper
nr_ae_FD=K_FD+1 #number of parallel AEs = K+1
loss_weight_FD=1 #lambda^FD in paper
nfft = 30 #number of points for DFT
norm_mode = "timeseries" #for calculation of DFT, should the timeseries have mean zero or each window?
type_setting = 'beta'

# %% [markdown]
# ## Generate data

# %%
# load time series from file 
# import json
# data_file = './data/quality_control_3.json'
# with open(data_file, mode='r') as f:
#     data = json.load(f)
#     series = data['series']
#     timeseries = series[0]['raw']
#     timeseries = np.array(timeseries)

# %%
# load hasc data 
# data_file = './data/preprocess/hasc_l2_norm.csv'
data_file = './data/hasc-111018-165936-acc.csv'
breakpoints_index_file = './data/preprocess/hasc_label_index.txt'
num_channels = 3

ts_df = pd.read_csv(data_file,header = None, names=['time', 'x', 'y', 'z'])
ts_df.head()
timeseries = ts_df[['x', 'y', 'z']].to_numpy()
timeseries = timeseries.T # change shape to (3, 39397)

breakpoints_df = pd.read_csv(breakpoints_index_file, header=None)
breakpoints_index = breakpoints_df[0].to_numpy()
breakpoints_index = breakpoints_index - window_size # change index because we reduce the length of breakpoints

# %%
'''
1. Generate time series, 
2. convert time series into window_TD
3. Convert time serites into window_FD
4. Create groundtruth
'''
timeseries_len = len(timeseries[0])
windows_TD = []
windows_FD = []
for series in timeseries:
    tmp_window_TD = utils.ts_to_windows(series, 0, window_size, 1)
    tmp_window_TD = utils.minmaxscale(tmp_window_TD,-1,1)
    tmp_windows_FD = utils.calc_fft(tmp_window_TD, nfft, norm_mode)

    windows_TD.append(tmp_window_TD)
    windows_FD.append(tmp_windows_FD)

# len(breakpoints) = len(timeseries) - 2*window_size + 1
# breakpoints_index = [179]
print(f'len: {len(breakpoints_index)}, value: {breakpoints_index}')
breakpoints = np.array([0] * (timeseries_len - 2*window_size + 1))

breakpoints[breakpoints_index] = [1]*len(breakpoints_index)
print(timeseries_len, len(breakpoints))
# Out:
# len: 39, value: [ 3859  5205  7712 10400 10465 12386 12984 13866 14145 14311 18282 18328
#  19801 20957 20986 21438 24136 24369 24718 24784 25114 25610 25680 26410
#  27308 27331 28001 28016 28296 29916 29972 30307 30678 30758 33467 34165
#  35429 37411 37687]
# 39397 39198

# %% [markdown]
# ## Train the autoencoders

# %%
shared_features_TD = []
shared_features_FD = []
for i in range(num_channels):
    print(f'train AE for channel: {i}')
    tmp_shared_features_TD = TIRE.train_AE(windows_TD[i], intermediate_dim_TD, latent_dim_TD, nr_shared_TD, nr_ae_TD, loss_weight_TD, nr_patience=40)
    tmp_shared_features_FD = TIRE.train_AE(windows_FD[i], intermediate_dim_FD, latent_dim_FD, nr_shared_FD, nr_ae_FD, loss_weight_FD, nr_patience=40)

    shared_features_TD.append(tmp_shared_features_TD)
    shared_features_FD.append(tmp_shared_features_FD)
# Out:
# train AE for channel: 0
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 3, 100)]     0           []
#
#  dense_18 (Dense)               (None, 3, 2)         202         ['input_13[0][0]']
#
#  dense_19 (Dense)               (None, 3, 1)         101         ['input_13[0][0]']
#
#  tf.concat_6 (TFOpLambda)       (None, 3, 3)         0           ['dense_18[0][0]',
#                                                                   'dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 3, 100)       400         ['tf.concat_6[0][0]']
#
# ==================================================================================================
# Total params: 703
# Trainable params: 703
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 2), second_shape: (None, 2, 2)
# Epoch 1/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0189
# Epoch 2/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0128
# Epoch 3/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0121
# Epoch 4/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0120
# Epoch 5/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0119
# Epoch 6/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0118
# Epoch 7/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0117
# Epoch 8/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0116
# Epoch 9/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0116
# Epoch 10/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0116
# Epoch 11/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0115
# Epoch 12/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0115
# Epoch 13/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0115
# Epoch 14/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0115
# Epoch 15/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0115
# Epoch 16/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0115
# Epoch 17/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 18/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 20/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 21/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 30/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 31/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 32/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0114
# Epoch 40/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 41/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 42/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 43/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0114
# Epoch 44/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 47/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 48/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 49/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 50/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 51/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 52/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 53/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 54/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 55/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 56/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 57/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 58/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 59/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 60/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 61/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 62/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 63/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 64/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 65/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 66/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 67/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 68/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 69/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 70/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 71/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 72/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 73/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 78/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 79/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 80/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 81/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 82/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 83/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 84/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 85/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 86/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 87/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 88/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 89/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 90/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 91/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0113
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 107/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 108/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 109/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 110/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 111/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 112/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 113/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 114/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 115/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 116/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 117/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 118/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 119/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 120/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 121/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 122/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 123/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 124/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 125/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 126/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 127/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 128/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 129/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 130/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 131/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 132/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 133/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 134/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 135/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 136/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 137/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 138/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 139/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 140/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 141/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 142/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 143/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 144/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 145/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 146/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 147/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 148/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 149/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 150/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 151/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 152/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 158/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 160/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 161/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 162/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 163/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 164/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 165/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 166/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 167/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 168/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 169/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 170/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 171/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 172/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 173/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 174/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 175/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 176/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 177/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 179/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 180/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 181/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 182/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 183/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 184/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 185/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 186/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 187/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 188/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 189/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 190/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 191/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 192/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 193/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 194/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 195/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 196/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 197/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 198/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 199/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# Epoch 200/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0113
# 1228/1228 [==============================] - 1s 1ms/step
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 3, 16)]      0           []
#
#  dense_21 (Dense)               (None, 3, 10)        170         ['input_15[0][0]']
#
#  dense_22 (Dense)               (None, 3, 1)         11          ['dense_21[0][0]']
#
#  dense_23 (Dense)               (None, 3, 0)         0           ['dense_21[0][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 3, 1)         0           ['dense_22[0][0]',
#                                                                   'dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 3, 10)        20          ['tf.concat_7[0][0]']
#
#  dense_25 (Dense)               (None, 3, 16)        176         ['dense_24[0][0]']
#
# ==================================================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 1), second_shape: (None, 2, 1)
# Epoch 1/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.1370
# Epoch 2/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0071
# Epoch 3/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 4/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 5/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 6/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 7/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 8/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0056
# Epoch 9/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0056
# Epoch 10/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0056
# Epoch 11/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0050
# Epoch 12/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0026
# Epoch 13/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0022
# Epoch 14/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0022
# Epoch 15/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 16/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 17/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 18/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 20/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 21/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 30/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 31/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 32/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0020
# Epoch 34/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 35/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 36/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 40/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 41/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 42/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 43/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 44/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 47/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 48/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 49/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 50/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 51/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 52/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 54/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 55/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 56/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 57/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 58/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 59/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 61/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 62/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 63/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 64/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 65/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 66/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 68/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 78/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 80/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 88/200
# 614/614 [==============================] - 2s 4ms/step - loss: 0.0018
# Epoch 89/200
# 614/614 [==============================] - 2s 3ms/step - loss: 0.0018
# Epoch 90/200
# 614/614 [==============================] - 2s 3ms/step - loss: 0.0018
# Epoch 91/200
# 614/614 [==============================] - 2s 3ms/step - loss: 0.0018
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 107/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 108/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 109/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 110/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 111/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 112/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 113/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 114/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 115/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 116/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 117/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 118/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 119/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 120/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 121/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 122/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 123/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 124/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 125/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 126/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 127/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 128/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 129/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 130/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 131/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 132/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 133/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 134/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 135/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 136/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 137/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 138/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 139/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 140/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 141/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 142/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 143/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 144/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 145/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 146/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 147/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 148/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 149/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 150/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 151/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 152/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 158/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 160/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 161/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 162/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 163/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 164/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 165/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 166/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 167/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 168/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 169/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 170/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 171/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 172/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 173/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 174/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 175/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 176/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 177/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 179/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 180/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 181/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 182/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 183/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 184/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 185/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 186/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 187/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 188/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 189/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 190/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 191/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 192/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 193/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 194/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 195/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 196/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 197/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 198/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 199/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 200/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0018
# 1228/1228 [==============================] - 1s 1ms/step
# train AE for channel: 1
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 3, 100)]     0           []
#
#  dense_26 (Dense)               (None, 3, 2)         202         ['input_17[0][0]']
#
#  dense_27 (Dense)               (None, 3, 1)         101         ['input_17[0][0]']
#
#  tf.concat_8 (TFOpLambda)       (None, 3, 3)         0           ['dense_26[0][0]',
#                                                                   'dense_27[0][0]']
#
#  dense_28 (Dense)               (None, 3, 100)       400         ['tf.concat_8[0][0]']
#
# ==================================================================================================
# Total params: 703
# Trainable params: 703
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 2), second_shape: (None, 2, 2)
# Epoch 1/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0228
# Epoch 2/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0138
# Epoch 3/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0131
# Epoch 4/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0129
# Epoch 5/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0127
# Epoch 6/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0126
# Epoch 7/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0126
# Epoch 8/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0126
# Epoch 9/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 10/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 11/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 12/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 13/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 14/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 15/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 16/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 17/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0125
# Epoch 18/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 20/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 21/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 30/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 31/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 32/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 40/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 41/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 42/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 43/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 44/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 47/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 48/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 49/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 50/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 51/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 52/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 54/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 55/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 56/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 57/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 58/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 59/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 61/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 62/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 63/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 64/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 65/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 66/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 68/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 78/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 88/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 89/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 90/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 91/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0124
# Epoch 107/200
# ...
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 6.6576e-04
# Epoch 20/200
# 614/614 [==============================] - 1s 2ms/step - loss: 6.2087e-04
# Epoch 21/200
# 614/614 [==============================] - 1s 2ms/step - loss: 5.8778e-04
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 5.6158e-04
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 5.3968e-04
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 5.2106e-04
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 5.0507e-04
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.9136e-04
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.8115e-04
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.7212e-04
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.6528e-04
# Epoch 30/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.5983e-04
# Epoch 31/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.5577e-04
# Epoch 32/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.5228e-04
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.4877e-04
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.4589e-04
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.4358e-04
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.4194e-04
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.4053e-04
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3825e-04
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3770e-04
# Epoch 40/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3536e-04
# Epoch 41/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3469e-04
# Epoch 42/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3324e-04
# Epoch 43/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3254e-04
# Epoch 44/200
# 614/614 [==============================] - 2s 3ms/step - loss: 4.3097e-04
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3162e-04
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.3051e-04
# Epoch 47/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2987e-04
# Epoch 48/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2992e-04
# Epoch 49/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2667e-04
# Epoch 50/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2716e-04
# Epoch 51/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2654e-04
# Epoch 52/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2526e-04
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2490e-04
# Epoch 54/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2432e-04
# Epoch 55/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2373e-04
# Epoch 56/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2349e-04
# Epoch 57/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2218e-04
# Epoch 58/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2386e-04
# Epoch 59/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2100e-04
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2280e-04
# Epoch 61/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2041e-04
# Epoch 62/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2061e-04
# Epoch 63/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.2027e-04
# Epoch 64/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1948e-04
# Epoch 65/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1923e-04
# Epoch 66/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1997e-04
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1964e-04
# Epoch 68/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1911e-04
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1798e-04
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1715e-04
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1677e-04
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1717e-04
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1656e-04
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1742e-04
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1702e-04
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1611e-04
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1429e-04
# Epoch 78/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1568e-04
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1504e-04
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1615e-04
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1430e-04
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1336e-04
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1292e-04
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1341e-04
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1340e-04
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1299e-04
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1248e-04
# Epoch 88/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1194e-04
# Epoch 89/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1353e-04
# Epoch 90/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1123e-04
# Epoch 91/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1099e-04
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1067e-04
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1102e-04
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1173e-04
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1264e-04
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1027e-04
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1091e-04
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0981e-04
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1031e-04
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.1000e-04
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0930e-04
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0937e-04
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0896e-04
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0921e-04
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0752e-04
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0843e-04
# Epoch 107/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0700e-04
# Epoch 108/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0736e-04
# Epoch 109/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0769e-04
# Epoch 110/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0797e-04
# Epoch 111/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0632e-04
# Epoch 112/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0731e-04
# Epoch 113/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0574e-04
# Epoch 114/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0748e-04
# Epoch 115/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0473e-04
# Epoch 116/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0722e-04
# Epoch 117/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0578e-04
# Epoch 118/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0549e-04
# Epoch 119/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0641e-04
# Epoch 120/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0473e-04
# Epoch 121/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0537e-04
# Epoch 122/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0435e-04
# Epoch 123/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0481e-04
# Epoch 124/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0411e-04
# Epoch 125/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0550e-04
# Epoch 126/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0376e-04
# Epoch 127/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0292e-04
# Epoch 128/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0273e-04
# Epoch 129/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0321e-04
# Epoch 130/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0536e-04
# Epoch 131/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0321e-04
# Epoch 132/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0373e-04
# Epoch 133/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0329e-04
# Epoch 134/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0149e-04
# Epoch 135/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0479e-04
# Epoch 136/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0143e-04
# Epoch 137/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0314e-04
# Epoch 138/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0315e-04
# Epoch 139/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0151e-04
# Epoch 140/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0191e-04
# Epoch 141/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0108e-04
# Epoch 142/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0111e-04
# Epoch 143/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0037e-04
# Epoch 144/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0084e-04
# Epoch 145/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0061e-04
# Epoch 146/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0065e-04
# Epoch 147/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0204e-04
# Epoch 148/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0121e-04
# Epoch 149/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9969e-04
# Epoch 150/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9926e-04
# Epoch 151/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0034e-04
# Epoch 152/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0036e-04
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0144e-04
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0039e-04
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9911e-04
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9958e-04
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9892e-04
# Epoch 158/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0118e-04
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9751e-04
# Epoch 160/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9860e-04
# Epoch 161/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0080e-04
# Epoch 162/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9966e-04
# Epoch 163/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9902e-04
# Epoch 164/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9867e-04
# Epoch 165/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9933e-04
# Epoch 166/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9757e-04
# Epoch 167/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9994e-04
# Epoch 168/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0001e-04
# Epoch 169/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9805e-04
# Epoch 170/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9712e-04
# Epoch 171/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9913e-04
# Epoch 172/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9811e-04
# Epoch 173/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9869e-04
# Epoch 174/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9686e-04
# Epoch 175/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9737e-04
# Epoch 176/200
# 614/614 [==============================] - 1s 2ms/step - loss: 4.0066e-04
# Epoch 177/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9789e-04
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9656e-04
# Epoch 179/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9849e-04
# Epoch 180/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9828e-04
# Epoch 181/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9627e-04
# Epoch 182/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9834e-04
# Epoch 183/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9693e-04
# Epoch 184/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9802e-04
# Epoch 185/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9710e-04
# Epoch 186/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9511e-04
# Epoch 187/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9729e-04
# Epoch 188/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9554e-04
# Epoch 189/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9687e-04
# Epoch 190/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9564e-04
# Epoch 191/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9703e-04
# Epoch 192/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9708e-04
# Epoch 193/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9530e-04
# Epoch 194/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9558e-04
# Epoch 195/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9626e-04
# Epoch 196/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9758e-04
# Epoch 197/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9471e-04
# Epoch 198/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9511e-04
# Epoch 199/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9590e-04
# Epoch 200/200
# 614/614 [==============================] - 1s 2ms/step - loss: 3.9643e-04
# 1228/1228 [==============================] - 2s 1ms/step

# %% [markdown]
# ## Postprocessing and peak detection

# %%
import os 

def create_folder_if_not_exist(folder_name):
    if os.path.exists(folder_name) == False:
        os.makedirs(folder_name)

# %%
#we calculate the smoothened dissimilarity measure and the corresponding prominence-based change point scores
from importlib import reload 

reload(TIRE)
print(f'shared_features_TD shape: {shared_features_TD[0].shape}')

for domain in ['TD', 'FD', 'both']:
    dissimilarities = []
    for i in range(num_channels):
        tmp_dissimilarities = TIRE.smoothened_dissimilarity_measures(shared_features_TD[i], shared_features_FD[i], domain, window_size)
        dissimilarities.append(tmp_dissimilarities)
    dissimilarities = np.array(dissimilarities)
    # save 
    create_folder_if_not_exist(f'./data/dissimilarities_{type_setting}')
    np.savetxt(f'./data/dissimilarities_{type_setting}/dissimilarities_{domain}.txt', dissimilarities, fmt='%.20f')
# Out:
# shared_features_TD shape: (39298, 2)

# %%
# load numpy from text

domain = 'both'
dissimilarities = np.loadtxt(f'./data/dissimilarities_{type_setting}/dissimilarities_{domain}.txt')

# %%
#parameters for plot
# import utils
from importlib import reload 
reload(utils)
time_start = 3000
time_stop = 6000
plot_prominences = True
'''
- green point: peak point based on simple comparasion with neighbour point (use scipy.signal)
- black line: disimilarity curve 
- vertical red line: groundtruth. But in this graph, it only use for the sake of example
- vertical blue: peak prominence (use scipy.singal)
'''
print('channel X')
utils.plot_cp(dissimilarities[0], time_start, time_stop, plot_prominences, breakpoints)
print('channel Y')
utils.plot_cp(dissimilarities[1], time_start, time_stop, plot_prominences, breakpoints)
print('channel Z')
utils.plot_cp(dissimilarities[2], time_start, time_stop, plot_prominences, breakpoints)
# Out:
# channel X
# channel Y
# channel Z

# %%
num_channels
# Out:
# 3

# %%
# get prominence for each channel 
prominence_all = []
for channel in range(num_channels):
    prominence_all.append(utils.new_peak_prominences(dissimilarities[channel])[0])

distance = np.array(prominence_all)
dis_threshold = np.mean(distance, axis = 1) # percentige for each axis 
distance_len = len(distance[0])
new_distance = np.zeros((distance_len)) # after combined change point accross channels
i = 0
while i < distance_len:
    potential_indexes = np.where(distance[:, i] > dis_threshold)[0]
    if len(potential_indexes) == 0:
        i += 1
        continue
    anchor_index = potential_indexes[0] # first chanel have 
    left_index, right_index = max(0, i), min(i + window_size, distance_len - 1)
    tmp = []
    for channel in range(num_channels):
        channel_distance = distance[channel][left_index: right_index]
        searching = np.where(channel_distance > dis_threshold[channel])[0]
        if len(searching) > 0:
            mean_index = math.floor(searching.mean())
            mean_value = channel_distance[searching].mean()

            tmp.append([mean_index, mean_value])
    tmp = np.array(tmp)
    if len(tmp) == num_channels: # hyperparameter
        # if the number of channel have change point <= num_channels/2 => ignore current index
        tmp = tmp.T # (channel = row, column = value)
        tmp_mean = tmp.mean(axis=1)
        new_distance[math.floor(left_index + tmp_mean[0])] = tmp_mean[1]

    # update i
    i += window_size

# %%
# combine pronimence of each axis 
reload(utils)

tol_distances = [300]
print(f'mode: {domain}')
auc = utils.get_auc_v2(new_distance,tol_distances, breakpoints)
# Out:
# mode: both
# peaks length: 66
# number elements > 0: 66
# [0.5615246770517826]
