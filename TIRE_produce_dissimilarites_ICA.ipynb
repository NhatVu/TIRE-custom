# %% [markdown]
# # CPD using TIRE

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.models import Model

import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from scipy.signal import find_peaks, peak_prominences
import warnings
import time, copy

import utils
import TIRE
import simulate
import math

# %% [markdown]
# ## Set parameters

# %% [markdown]
# #### alpha settings

# %%
# window_size = 100
# domain = "both" #choose from: TD (time domain), FD (frequency domain) or both

# #parameters TD
# intermediate_dim_TD=0
# latent_dim_TD=1 #h^TD in paper
# nr_shared_TD=1 #s^TD in paper
# K_TD = 2 #as in paper
# nr_ae_TD= K_TD+1 #number of parallel AEs = K+1
# loss_weight_TD=1 #lambda_TD in paper

# #parameters FD
# intermediate_dim_FD=0
# latent_dim_FD=1 #h^FD in paper
# nr_shared_FD=1 #s^FD in paper
# K_FD = 2 #as in paper
# nr_ae_FD=K_FD+1 #number of parallel AEs = K+1
# loss_weight_FD=1 #lambda^FD in paper
# nfft = 30 #number of points for DFT
# norm_mode = "timeseries" #for calculation of DFT, should the timeseries have mean zero or each window?
# type_setting = 'alpha'

# %% [markdown]
# #### beta settings

# %%
window_size = 100
domain = "both" #choose from: TD (time domain), FD (frequency domain) or both

#parameters TD
intermediate_dim_TD=0
latent_dim_TD=3 #h^TD in paper
nr_shared_TD=2 #s^TD in paper
K_TD = 2 #as in paper
nr_ae_TD= K_TD+1 #number of parallel AEs = K+1
loss_weight_TD=1 #lambda_TD in paper

#parameters FD
intermediate_dim_FD=10
latent_dim_FD=1 #h^FD in paper
nr_shared_FD=1 #s^FD in paper
K_FD = 2 #as in paper
nr_ae_FD=K_FD+1 #number of parallel AEs = K+1
loss_weight_FD=1 #lambda^FD in paper
nfft = 30 #number of points for DFT
norm_mode = "timeseries" #for calculation of DFT, should the timeseries have mean zero or each window?
type_setting = 'beta'

# %% [markdown]
# ## Generate data

# %%
# load time series from file 
# import json
# data_file = './data/quality_control_3.json'
# with open(data_file, mode='r') as f:
#     data = json.load(f)
#     series = data['series']
#     timeseries = series[0]['raw']
#     timeseries = np.array(timeseries)

# %%
# load hasc data 
# data_file = './data/preprocess/hasc_l2_norm.csv'
data_file = './data/hasc-111018-165936-acc.csv'
breakpoints_index_file = './data/preprocess/hasc_label_index.txt'
num_channels = 3

ts_df = pd.read_csv(data_file,header = None, names=['time', 'x', 'y', 'z'])
ts_df.head()
timeseries = ts_df[['x', 'y', 'z']].to_numpy()

# perform ICA
from sklearn.decomposition import FastICA
transformer = FastICA(n_components=None,
         random_state=0,
         whiten='unit-variance')
timeseries = transformer.fit_transform(timeseries)
timeseries = timeseries.T # change shape to (3, 39397)

print(f'timeseries shape: {timeseries.shape}')
breakpoints_df = pd.read_csv(breakpoints_index_file, header=None)
breakpoints_index = breakpoints_df[0].to_numpy()
breakpoints_index = breakpoints_index - window_size # change index because we reduce the length of breakpoints
# Out:
# timeseries shape: (3, 39397)

# %%
timeseries
# Out:
# array([[-0.00496295, -0.00512458, -0.00494161, ...,  0.00723428,
#          0.00798659,  0.0075945 ],
#        [-0.00290323, -0.00279459, -0.00290923, ..., -0.03399997,
#         -0.03417508, -0.03370458],
#        [ 0.00287407,  0.00276599,  0.00295926, ..., -0.00075751,
#         -0.00056762, -0.0005679 ]])

# %%
'''
1. Generate time series, 
2. convert time series into window_TD
3. Convert time serites into window_FD
4. Create groundtruth
'''
timeseries_len = len(timeseries[0])
windows_TD = []
windows_FD = []
for series in timeseries:
    tmp_window_TD = utils.ts_to_windows(series, 0, window_size, 1)
    tmp_window_TD = utils.minmaxscale(tmp_window_TD,-1,1)
    tmp_windows_FD = utils.calc_fft(tmp_window_TD, nfft, norm_mode)

    windows_TD.append(tmp_window_TD)
    windows_FD.append(tmp_windows_FD)

# len(breakpoints) = len(timeseries) - 2*window_size + 1
# breakpoints_index = [179]
print(f'len: {len(breakpoints_index)}, value: {breakpoints_index}')
breakpoints = np.array([0] * (timeseries_len - 2*window_size + 1))

breakpoints[breakpoints_index] = [1]*len(breakpoints_index)
print(timeseries_len, len(breakpoints))
# Out:
# len: 39, value: [ 3859  5205  7712 10400 10465 12386 12984 13866 14145 14311 18282 18328
#  19801 20957 20986 21438 24136 24369 24718 24784 25114 25610 25680 26410
#  27308 27331 28001 28016 28296 29916 29972 30307 30678 30758 33467 34165
#  35429 37411 37687]
# 39397 39198

# %% [markdown]
# ## Train the autoencoders

# %%
shared_features_TD = []
shared_features_FD = []
for i in range(num_channels):
    print(f'train AE for channel: {i}')
    tmp_shared_features_TD = TIRE.train_AE(windows_TD[i], intermediate_dim_TD, latent_dim_TD, nr_shared_TD, nr_ae_TD, loss_weight_TD, nr_patience=40)
    tmp_shared_features_FD = TIRE.train_AE(windows_FD[i], intermediate_dim_FD, latent_dim_FD, nr_shared_FD, nr_ae_FD, loss_weight_FD, nr_patience=40)

    shared_features_TD.append(tmp_shared_features_TD)
    shared_features_FD.append(tmp_shared_features_FD)
# Out:
# train AE for channel: 0
# Model: "model_36"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 3, 100)]     0           []
#
#  dense_36 (Dense)               (None, 3, 2)         202         ['input_25[0][0]']
#
#  dense_37 (Dense)               (None, 3, 1)         101         ['input_25[0][0]']
#
#  tf.concat_12 (TFOpLambda)      (None, 3, 3)         0           ['dense_36[0][0]',
#                                                                   'dense_37[0][0]']
#
#  dense_38 (Dense)               (None, 3, 100)       400         ['tf.concat_12[0][0]']
#
# ==================================================================================================
# Total params: 703
# Trainable params: 703
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 2), second_shape: (None, 2, 2)
# Epoch 1/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0170
# Epoch 2/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0116
# Epoch 3/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0110
# Epoch 4/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0108
# Epoch 5/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0107
# Epoch 6/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0107
# Epoch 7/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0106
# Epoch 8/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0106
# Epoch 9/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0106
# Epoch 10/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0106
# Epoch 11/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 12/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 13/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 14/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 15/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 16/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 17/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 18/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 20/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 21/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 22/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 23/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 24/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 25/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 26/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 27/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 28/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 29/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 30/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 31/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 32/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 33/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 37/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 38/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 39/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 40/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 41/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 42/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 43/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 44/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 45/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 46/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 47/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 48/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 49/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 50/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 51/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 52/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 54/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 55/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 56/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 57/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 58/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 59/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 61/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 62/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 63/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 64/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 65/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 66/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 68/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 69/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 71/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 72/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 73/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 75/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 76/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 77/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 78/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 79/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0105
# Epoch 82/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0105
# Epoch 83/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 84/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 85/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 86/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 87/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 88/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 89/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 90/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 91/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 92/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 93/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 94/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 95/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 96/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 97/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 98/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 99/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 100/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 102/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 104/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 107/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 108/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 109/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 110/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 111/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 112/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 113/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 114/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 115/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 116/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 117/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 118/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 119/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 120/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 121/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 122/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 123/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 124/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 125/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 126/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 127/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 128/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 129/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 130/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 131/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 132/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 133/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 134/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 135/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 136/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 137/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 138/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 139/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 140/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 141/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 142/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 143/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 144/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 145/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 146/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 147/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 148/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 149/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 150/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 151/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 152/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 158/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 160/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 161/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 162/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 163/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 164/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 165/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 166/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 167/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 168/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 169/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 170/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 171/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 172/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 173/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 174/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 175/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 176/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 177/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 179/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 180/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 181/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 182/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 183/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 184/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 185/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 186/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 187/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 188/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 189/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 190/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 191/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 192/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 193/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 194/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 195/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 196/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# Epoch 197/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 198/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 199/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0104
# Epoch 200/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0104
# 1228/1228 [==============================] - 1s 906us/step
# Model: "model_39"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 3, 16)]      0           []
#
#  dense_39 (Dense)               (None, 3, 10)        170         ['input_27[0][0]']
#
#  dense_40 (Dense)               (None, 3, 1)         11          ['dense_39[0][0]']
#
#  dense_41 (Dense)               (None, 3, 0)         0           ['dense_39[0][0]']
#
#  tf.concat_13 (TFOpLambda)      (None, 3, 1)         0           ['dense_40[0][0]',
#                                                                   'dense_41[0][0]']
#
#  dense_42 (Dense)               (None, 3, 10)        20          ['tf.concat_13[0][0]']
#
#  dense_43 (Dense)               (None, 3, 16)        176         ['dense_42[0][0]']
#
# ==================================================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 1), second_shape: (None, 2, 1)
# Epoch 1/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.1128
# Epoch 2/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0062
# Epoch 3/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0050
# Epoch 4/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0048
# Epoch 5/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0047
# Epoch 6/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0042
# Epoch 7/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0032
# Epoch 8/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0027
# Epoch 9/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0021
# Epoch 10/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 11/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 12/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 13/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 14/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 15/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 16/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 17/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 18/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 19/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 20/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 21/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 22/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 23/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 24/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 25/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 26/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0017
# Epoch 27/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 28/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 29/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 30/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 31/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 32/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 33/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 34/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 35/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 36/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 37/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 38/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 39/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 40/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 41/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 42/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 43/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 44/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 45/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 46/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 47/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 48/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 49/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 50/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 51/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 52/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 53/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 54/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 55/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 56/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 57/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 58/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 59/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 60/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 61/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 62/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 63/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 64/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 65/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 66/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 67/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 68/200
# 614/614 [==============================] - 1s 1ms/step - loss: 0.0015
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 78/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 88/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 89/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 90/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 91/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 107/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 108/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 109/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 110/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 111/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 112/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 113/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 114/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 115/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 116/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 117/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 118/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 119/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 120/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 121/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 122/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 123/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 124/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 125/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 126/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 127/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 128/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 129/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 130/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 131/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 132/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 133/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 134/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 135/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 136/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 137/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 138/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 139/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 140/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 141/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 142/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 143/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 144/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 145/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 146/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 147/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 148/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 149/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 150/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 151/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 152/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 158/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 160/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 161/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 162/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 163/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 164/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 165/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 166/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 167/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 168/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 169/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 170/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 171/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 172/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 173/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 174/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 175/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 176/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 177/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 179/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 180/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 181/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 182/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 183/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 184/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 185/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 186/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 187/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 188/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 189/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 190/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 191/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 192/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 193/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 194/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 195/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 196/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 197/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 198/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 199/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# Epoch 200/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0015
# 1228/1228 [==============================] - 1s 1ms/step
# train AE for channel: 1
# Model: "model_42"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_29 (InputLayer)          [(None, 3, 100)]     0           []
#
#  dense_44 (Dense)               (None, 3, 2)         202         ['input_29[0][0]']
#
#  dense_45 (Dense)               (None, 3, 1)         101         ['input_29[0][0]']
#
#  tf.concat_14 (TFOpLambda)      (None, 3, 3)         0           ['dense_44[0][0]',
#                                                                   'dense_45[0][0]']
#
#  dense_46 (Dense)               (None, 3, 100)       400         ['tf.concat_14[0][0]']
#
# ==================================================================================================
# Total params: 703
# Trainable params: 703
# Non-trainable params: 0
# __________________________________________________________________________________________________
# nr_ae: 3, first shape: (None, 2, 2), second_shape: (None, 2, 2)
# Epoch 1/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0094
# Epoch 2/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 3/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0050
# Epoch 4/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0047
# Epoch 5/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0047
# Epoch 6/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 7/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 8/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 9/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 10/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 11/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 12/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 13/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 14/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 15/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 16/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 17/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 18/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 20/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 21/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0046
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 30/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 31/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 32/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 40/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 41/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 42/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 43/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 44/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 47/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 48/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 49/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 50/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 51/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 52/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 54/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 55/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 56/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 57/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 58/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 59/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 61/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 62/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 63/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 64/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 65/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 66/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 68/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 78/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 88/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 89/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 90/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 91/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0045
# Epoch 107/200
# ...
# Epoch 19/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 20/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 21/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 22/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 23/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0011
# Epoch 24/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 25/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 26/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 27/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 28/200
# 614/614 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 29/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.9387e-04
# Epoch 30/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.8726e-04
# Epoch 31/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.8257e-04
# Epoch 32/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.7649e-04
# Epoch 33/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.7353e-04
# Epoch 34/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.7090e-04
# Epoch 35/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.6677e-04
# Epoch 36/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.6390e-04
# Epoch 37/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.6234e-04
# Epoch 38/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.6018e-04
# Epoch 39/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.5765e-04
# Epoch 40/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.5463e-04
# Epoch 41/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.5479e-04
# Epoch 42/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.5098e-04
# Epoch 43/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.5293e-04
# Epoch 44/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.4773e-04
# Epoch 45/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.4783e-04
# Epoch 46/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.4620e-04
# Epoch 47/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.4045e-04
# Epoch 48/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.3683e-04
# Epoch 49/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.3619e-04
# Epoch 50/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.3271e-04
# Epoch 51/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.3434e-04
# Epoch 52/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.3044e-04
# Epoch 53/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2867e-04
# Epoch 54/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2817e-04
# Epoch 55/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2940e-04
# Epoch 56/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2346e-04
# Epoch 57/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2570e-04
# Epoch 58/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2300e-04
# Epoch 59/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2090e-04
# Epoch 60/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2325e-04
# Epoch 61/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2246e-04
# Epoch 62/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2071e-04
# Epoch 63/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1878e-04
# Epoch 64/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1986e-04
# Epoch 65/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.2004e-04
# Epoch 66/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1725e-04
# Epoch 67/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1783e-04
# Epoch 68/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1653e-04
# Epoch 69/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1756e-04
# Epoch 70/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1862e-04
# Epoch 71/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1718e-04
# Epoch 72/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1426e-04
# Epoch 73/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1587e-04
# Epoch 74/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1526e-04
# Epoch 75/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1571e-04
# Epoch 76/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1428e-04
# Epoch 77/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1341e-04
# Epoch 78/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1365e-04
# Epoch 79/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1224e-04
# Epoch 80/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1406e-04
# Epoch 81/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1157e-04
# Epoch 82/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1390e-04
# Epoch 83/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1018e-04
# Epoch 84/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1089e-04
# Epoch 85/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1226e-04
# Epoch 86/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1033e-04
# Epoch 87/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1053e-04
# Epoch 88/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.1040e-04
# Epoch 89/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0777e-04
# Epoch 90/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0918e-04
# Epoch 91/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0826e-04
# Epoch 92/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0612e-04
# Epoch 93/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0797e-04
# Epoch 94/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0644e-04
# Epoch 95/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0739e-04
# Epoch 96/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0754e-04
# Epoch 97/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0268e-04
# Epoch 98/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0295e-04
# Epoch 99/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0177e-04
# Epoch 100/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0144e-04
# Epoch 101/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0007e-04
# Epoch 102/200
# 614/614 [==============================] - 1s 2ms/step - loss: 9.0079e-04
# Epoch 103/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9880e-04
# Epoch 104/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9837e-04
# Epoch 105/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9749e-04
# Epoch 106/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9538e-04
# Epoch 107/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9528e-04
# Epoch 108/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9448e-04
# Epoch 109/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9395e-04
# Epoch 110/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9329e-04
# Epoch 111/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9281e-04
# Epoch 112/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9020e-04
# Epoch 113/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8911e-04
# Epoch 114/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9111e-04
# Epoch 115/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.9131e-04
# Epoch 116/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8851e-04
# Epoch 117/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8790e-04
# Epoch 118/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8649e-04
# Epoch 119/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8649e-04
# Epoch 120/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8786e-04
# Epoch 121/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8552e-04
# Epoch 122/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8624e-04
# Epoch 123/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8576e-04
# Epoch 124/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8291e-04
# Epoch 125/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8659e-04
# Epoch 126/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8203e-04
# Epoch 127/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8440e-04
# Epoch 128/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8329e-04
# Epoch 129/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8367e-04
# Epoch 130/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8129e-04
# Epoch 131/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7907e-04
# Epoch 132/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7919e-04
# Epoch 133/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7995e-04
# Epoch 134/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7901e-04
# Epoch 135/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.8315e-04
# Epoch 136/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7961e-04
# Epoch 137/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7776e-04
# Epoch 138/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7721e-04
# Epoch 139/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7783e-04
# Epoch 140/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7809e-04
# Epoch 141/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7542e-04
# Epoch 142/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7728e-04
# Epoch 143/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7537e-04
# Epoch 144/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7768e-04
# Epoch 145/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7589e-04
# Epoch 146/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7351e-04
# Epoch 147/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7483e-04
# Epoch 148/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7578e-04
# Epoch 149/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7465e-04
# Epoch 150/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7613e-04
# Epoch 151/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7384e-04
# Epoch 152/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7097e-04
# Epoch 153/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7075e-04
# Epoch 154/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7330e-04
# Epoch 155/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7265e-04
# Epoch 156/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7196e-04
# Epoch 157/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7137e-04
# Epoch 158/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.7410e-04
# Epoch 159/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6902e-04
# Epoch 160/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6731e-04
# Epoch 161/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6817e-04
# Epoch 162/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6893e-04
# Epoch 163/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6689e-04
# Epoch 164/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6609e-04
# Epoch 165/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6396e-04
# Epoch 166/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6423e-04
# Epoch 167/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6833e-04
# Epoch 168/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6226e-04
# Epoch 169/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6418e-04
# Epoch 170/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6170e-04
# Epoch 171/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6133e-04
# Epoch 172/200
# 614/614 [==============================] - 2s 3ms/step - loss: 8.6011e-04
# Epoch 173/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5962e-04
# Epoch 174/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5889e-04
# Epoch 175/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.6050e-04
# Epoch 176/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5272e-04
# Epoch 177/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5797e-04
# Epoch 178/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5417e-04
# Epoch 179/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5243e-04
# Epoch 180/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5410e-04
# Epoch 181/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5117e-04
# Epoch 182/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5091e-04
# Epoch 183/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.5494e-04
# Epoch 184/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.5304e-04
# Epoch 185/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4672e-04
# Epoch 186/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.5055e-04
# Epoch 187/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4864e-04
# Epoch 188/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4664e-04
# Epoch 189/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4890e-04
# Epoch 190/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4687e-04
# Epoch 191/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4571e-04
# Epoch 192/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4479e-04
# Epoch 193/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4036e-04
# Epoch 194/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.5059e-04
# Epoch 195/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4108e-04
# Epoch 196/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4025e-04
# Epoch 197/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4442e-04
# Epoch 198/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.4222e-04
# Epoch 199/200
# 614/614 [==============================] - 1s 1ms/step - loss: 8.3752e-04
# Epoch 200/200
# 614/614 [==============================] - 1s 2ms/step - loss: 8.3961e-04
# 1228/1228 [==============================] - 1s 1ms/step

# %% [markdown]
# ## Postprocessing and peak detection

# %%
import os 

def create_folder_if_not_exist(folder_name):
    if os.path.exists(folder_name) == False:
        os.makedirs(folder_name)

# %%
#we calculate the smoothened dissimilarity measure and the corresponding prominence-based change point scores
from importlib import reload 

reload(TIRE)
print(f'shared_features_TD shape: {shared_features_TD[0].shape}')

for domain in ['TD', 'FD', 'both']:
    dissimilarities = []
    for i in range(num_channels):
        tmp_dissimilarities = TIRE.smoothened_dissimilarity_measures(shared_features_TD[i], shared_features_FD[i], domain, window_size)
        dissimilarities.append(tmp_dissimilarities)
    dissimilarities = np.array(dissimilarities)
    # save 
    create_folder_if_not_exist(f'./data/dissimilarities_ICA_{type_setting}')
    np.savetxt(f'./data/dissimilarities_ICA_{type_setting}/dissimilarities_{domain}.txt', dissimilarities, fmt='%.20f')
# Out:
# shared_features_TD shape: (39298, 2)

# %%
#parameters for plot
# import utils
# from importlib import reload 
# reload(utils)
# time_start = 3000
# time_stop = 6000
# plot_prominences = True
# '''
# - green point: peak point based on simple comparasion with neighbour point (use scipy.signal)
# - black line: disimilarity curve 
# - vertical red line: groundtruth. But in this graph, it only use for the sake of example
# - vertical blue: peak prominence (use scipy.singal)
# '''
# print('channel X')
# utils.plot_cp(dissimilarities[0], time_start, time_stop, plot_prominences, breakpoints)
# print('channel Y')
# utils.plot_cp(dissimilarities[1], time_start, time_stop, plot_prominences, breakpoints)
# print('channel Z')
# utils.plot_cp(dissimilarities[2], time_start, time_stop, plot_prominences, breakpoints)

# %%
def combine_cp_and_cal_auc(dissimilarities, threshold='mean'):
    # get prominence for each channel 
    prominence_all = []
    for channel in range(num_channels):
        prominence_all.append(utils.new_peak_prominences(dissimilarities[channel])[0])

    distance = np.array(prominence_all)
    dis_threshold = []
    if threshold == 'mean':
        dis_threshold = np.mean(distance, axis = 1) # percentige for each axis 
    elif isinstance(threshold, int):
        dis_threshold = np.percentile(dissimilarities, q=[threshold], axis=1)[0]
    else:
        print('threshold is wrong type. Please insert "mean" or percentage integer')
    print(f'dis_threshold: {dis_threshold}')
    distance_len = len(distance[0])
    new_distance = np.zeros((distance_len)) # after combined change point accross channels
    i = 0
    while i < distance_len:
        potential_indexes = np.where(distance[:, i] > dis_threshold)[0]
        if len(potential_indexes) == 0:
            i += 1
            continue
        anchor_index = potential_indexes[0] # first chanel have 
        left_index, right_index = max(0, i), min(i + window_size, distance_len - 1)
        tmp = []
        for channel in range(num_channels):
            channel_distance = distance[channel][left_index: right_index]
            searching = np.where(channel_distance > dis_threshold[channel])[0]
            if len(searching) > 0:
                mean_index = math.floor(searching.mean())
                mean_value = channel_distance[searching].mean()

                tmp.append([mean_index, mean_value])
        tmp = np.array(tmp)
        if len(tmp) == num_channels: # hyperparameter
            # if the number of channel have change point <= num_channels/2 => ignore current index
            tmp = tmp.T # (channel = row, column = value)
            tmp_mean = tmp.mean(axis=1)
            new_distance[math.floor(left_index + tmp_mean[0])] = tmp_mean[1]

        # update i
        i += window_size

    # combine pronimence of each axis 
    tol_distances = [300]
    print(f'mode: {domain}, new_distance_shape: {new_distance.shape}')

    auc = utils.get_auc_v2(new_distance,tol_distances, breakpoints)

# %%
# load numpy from text
from importlib import reload
reload(utils)
domains = ['TD', 'FD', 'both']
for domain in domains:
    dissimilarities = np.loadtxt(f'./data/dissimilarities_ICA_{type_setting}/dissimilarities_{domain}.txt')
    combine_cp_and_cal_auc(dissimilarities, 'mean')
# Out:
# dis_threshold: [0.0015059  0.00465174 0.00039365]
# mode: TD, new_distance_shape: (39198,)
# peaks length: 22
# number elements > 0: 22
# [0.2957441452288363]
# dis_threshold: [0.00331241 0.00165497 0.00217463]
# mode: FD, new_distance_shape: (39198,)
# peaks length: 45
# number elements > 0: 45
# [0.5423503821686853]
# dis_threshold: [0.00045742 0.00036358 0.00014848]
# mode: both, new_distance_shape: (39198,)
# peaks length: 36
# number elements > 0: 36
# [0.5102222965315741]
